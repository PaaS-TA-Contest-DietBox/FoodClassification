# %% [markdown]
# # Import Library

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
# %matplotlib inline

from glob import glob
from tqdm import tqdm

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# #### Sed Seed

# %%
SEED = 42

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

seed_everything(SEED)

# %% [markdown]
# #### Config

# %%
DATA_PATH = f'../Datasets/kfood/'

size = 224
batch_size = 256

# %% [markdown]
# # Load Data

# %%
target_lists = glob(f'{DATA_PATH}/*')

# %%
len(target_lists)
# Out:
# 150

# %%
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    rescale=1./255.,
)

datagenerator = datagen.flow_from_directory(
    DATA_PATH,
    target_size=(size, size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True, 
)
# Out:
# Found 150513 images belonging to 150 classes.

# %%
f, l = next(iter(datagenerator))
plt.imshow(f[0])
plt.title(np.argmax(l))
plt.show()

# %%
target_lists.sort()

# %%
target_lists
# Out:
# ['../Datasets/kfood/가지볶음',
#  '../Datasets/kfood/간장게장',
#  '../Datasets/kfood/갈비구이',
#  '../Datasets/kfood/갈비찜',
#  '../Datasets/kfood/갈비탕',
#  '../Datasets/kfood/갈치구이',
#  '../Datasets/kfood/갈치조림',
#  '../Datasets/kfood/감자전',
#  '../Datasets/kfood/감자조림',
#  '../Datasets/kfood/감자채볶음',
#  '../Datasets/kfood/감자탕',
#  '../Datasets/kfood/갓김치',
#  '../Datasets/kfood/건새우볶음',
#  '../Datasets/kfood/경단',
#  '../Datasets/kfood/계란국',
#  '../Datasets/kfood/계란말이',
#  '../Datasets/kfood/계란찜',
#  '../Datasets/kfood/계란후라이',
#  '../Datasets/kfood/고등어구이',
#  '../Datasets/kfood/고등어조림',
#  '../Datasets/kfood/고사리나물',
#  '../Datasets/kfood/고추장진미채볶음',
#  '../Datasets/kfood/고추튀김',
#  '../Datasets/kfood/곰탕_설렁탕',
#  '../Datasets/kfood/곱창구이',
#  '../Datasets/kfood/곱창전골',
#  '../Datasets/kfood/과메기',
#  '../Datasets/kfood/김밥',
#  '../Datasets/kfood/김치볶음밥',
#  '../Datasets/kfood/김치전',
#  '../Datasets/kfood/김치찌개',
#  '../Datasets/kfood/김치찜',
#  '../Datasets/kfood/깍두기',
#  '../Datasets/kfood/깻잎장아찌',
#  '../Datasets/kfood/꼬막찜',
#  '../Datasets/kfood/꽁치조림',
#  '../Datasets/kfood/꽈리고추무침',
#  '../Datasets/kfood/꿀떡',
#  '../Datasets/kfood/나박김치',
#  '../Datasets/kfood/누룽지',
#  '../Datasets/kfood/닭갈비',
#  '../Datasets/kfood/닭계장',
#  '../Datasets/kfood/닭볶음탕',
#  '../Datasets/kfood/더덕구이',
#  '../Datasets/kfood/도라지무침',
#  '../Datasets/kfood/도토리묵',
#  '../Datasets/kfood/동그랑땡',
#  '../Datasets/kfood/동태찌개',
#  '../Datasets/kfood/된장찌개',
#  '../Datasets/kfood/두부김치',
#  '../Datasets/kfood/두부조림',
#  '../Datasets/kfood/땅콩조림',
#  '../Datasets/kfood/떡갈비',
#  '../Datasets/kfood/떡국_만두국',
#  '../Datasets/kfood/떡꼬치',
#  '../Datasets/kfood/떡볶이',
#  '../Datasets/kfood/라면',
#  '../Datasets/kfood/라볶이',
#  '../Datasets/kfood/막국수',
#  '../Datasets/kfood/만두',
#  '../Datasets/kfood/매운탕',
#  '../Datasets/kfood/멍게',
#  '../Datasets/kfood/메추리알장조림',
#  '../Datasets/kfood/멸치볶음',
#  '../Datasets/kfood/무국',
#  '../Datasets/kfood/무생채',
#  '../Datasets/kfood/물냉면',
#  '../Datasets/kfood/물회',
#  '../Datasets/kfood/미역국',
#  '../Datasets/kfood/미역줄기볶음',
#  '../Datasets/kfood/배추김치',
#  '../Datasets/kfood/백김치',
#  '../Datasets/kfood/보쌈',
#  '../Datasets/kfood/부추김치',
#  '../Datasets/kfood/북엇국',
#  '../Datasets/kfood/불고기',
#  '../Datasets/kfood/비빔냉면',
#  '../Datasets/kfood/비빔밥',
#  '../Datasets/kfood/산낙지',
#  '../Datasets/kfood/삼겹살',
#  '../Datasets/kfood/삼계탕',
#  '../Datasets/kfood/새우볶음밥',
#  '../Datasets/kfood/새우튀김',
#  '../Datasets/kfood/생선전',
#  '../Datasets/kfood/소세지볶음',
#  '../Datasets/kfood/송편',
#  '../Datasets/kfood/수육',
#  '../Datasets/kfood/수정과',
#  '../Datasets/kfood/수제비',
#  '../Datasets/kfood/숙주나물',
#  '../Datasets/kfood/순대',
#  '../Datasets/kfood/순두부찌개',
#  '../Datasets/kfood/시금치나물',
#  '../Datasets/kfood/시래기국',
#  '../Datasets/kfood/식혜',
#  '../Datasets/kfood/알밥',
#  '../Datasets/kfood/애호박볶음',
#  '../Datasets/kfood/약과',
#  '../Datasets/kfood/약식',
#  '../Datasets/kfood/양념게장',
#  '../Datasets/kfood/양념치킨',
#  '../Datasets/kfood/어묵볶음',
#  '../Datasets/kfood/연근조림',
#  '../Datasets/kfood/열무국수',
#  '../Datasets/kfood/열무김치',
#  '../Datasets/kfood/오이소박이',
#  '../Datasets/kfood/오징어채볶음',
#  '../Datasets/kfood/오징어튀김',
#  '../Datasets/kfood/우엉조림',
#  '../Datasets/kfood/유부초밥',
#  '../Datasets/kfood/육개장',
#  '../Datasets/kfood/육회',
#  '../Datasets/kfood/잔치국수',
#  '../Datasets/kfood/잡곡밥',
#  '../Datasets/kfood/잡채',
#  '../Datasets/kfood/장어구이',
#  '../Datasets/kfood/장조림',
#  '../Datasets/kfood/전복죽',
#  '../Datasets/kfood/젓갈',
#  '../Datasets/kfood/제육볶음',
#  '../Datasets/kfood/조개구이',
#  '../Datasets/kfood/조기구이',
#  '../Datasets/kfood/족발',
#  '../Datasets/kfood/주꾸미볶음',
#  '../Datasets/kfood/주먹밥',
#  '../Datasets/kfood/짜장면',
#  '../Datasets/kfood/짬뽕',
#  '../Datasets/kfood/쫄면',
#  '../Datasets/kfood/찜닭',
#  '../Datasets/kfood/총각김치',
#  '../Datasets/kfood/추어탕',
#  '../Datasets/kfood/칼국수',
#  '../Datasets/kfood/코다리조림',
#  '../Datasets/kfood/콩국수',
#  '../Datasets/kfood/콩나물국',
#  '../Datasets/kfood/콩나물무침',
#  '../Datasets/kfood/콩자반',
#  '../Datasets/kfood/파김치',
#  '../Datasets/kfood/파전',
#  '../Datasets/kfood/편육',
#  '../Datasets/kfood/피자',
#  '../Datasets/kfood/한과',
#  '../Datasets/kfood/해물찜',
#  '../Datasets/kfood/호박전',
#  '../Datasets/kfood/호박죽',
#  '../Datasets/kfood/홍어무침',
#  '../Datasets/kfood/황태구이',
#  '../Datasets/kfood/회무침',
#  '../Datasets/kfood/후라이드치킨',
#  '../Datasets/kfood/훈제오리']
